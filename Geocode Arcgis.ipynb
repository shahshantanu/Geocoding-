# %%
import pandas as pd
import numpy as np 
from arcgis.gis import GIS
from getpass import getpass
from arcgis.geocoding import batch_geocode
import csv

# %%
api_key = "AIzaSyDiuEDivm4tp6kRQxyYkB7CdKaNXbnO6as"

# %%
df = pd.DataFrame(pd.read_excel(r"D:\Desktop\pincode.xlsx"))

# %%
df
# Out:
#         pincode
# 0        504273
# 1        504293
# 2        504307
# 3        504001
# 4        504001
# ...         ...
# 154792   721649
# 154793   721151
# 154794   721626
# 154795   721139
# 154796   721648
#
# [154797 rows x 1 columns]

# %%
Coordinates = df["pincode"].tolist()

# %%
Coordinates
# Out:
# [504273,
#  504293,
#  504307,
#  504001,
#  504001,
#  504251,
#  504273,
#  504251,
#  504309,
#  504201,
#  504110,
#  504202,
#  504296,
#  504231,
#  504109,
#  504201,
#  504299,
#  504002,
#  504201,
#  504204,
#  504312,
#  504313,
#  504101,
#  504293,
#  504201,
#  504204,
#  504293,
#  504299,
#  504205,
#  504203,
#  504295,
#  504106,
#  504306,
#  504299,
#  504296,
#  504101,
#  504304,
#  504203,
#  504299,
#  504309,
#  504202,
#  504251,
#  504251,
#  504103,
#  504001,
#  504103,
#  504308,
#  504204,
#  504311,
#  504002,
#  504273,
#  504103,
#  504103,
#  504001,
#  504304,
#  504273,
#  504101,
#  504311,
#  504306,
#  504304,
#  504273,
#  504101,
#  504307,
#  504110,
#  504272,
#  504101,
#  504251,
#  504251,
#  504323,
#  504293,
#  504272,
#  504002,
#  504215,
#  504311,
#  504309,
#  504103,
#  504296,
#  504346,
#  504103,
#  504110,
#  504002,
#  504201,
#  504296,
#  504205,
#  504299,
#  504299,
#  504304,
#  504310,
#  504294,
#  504306,
# ...

# %%
df_test = df.copy()

# %%
df_test
# Out:
#         pincode
# 0        504273
# 1        504293
# 2        504307
# 3        504001
# 4        504001
# ...         ...
# 154792   721649
# 154793   721151
# 154794   721626
# 154795   721139
# 154796   721648
#
# [154797 rows x 1 columns]

# %%
df_add = pd.DataFrame(pd.read_excel(r"D:\Desktop\Addresses.xlsx")) 
df_add
# Out:
#                                                   Address
# 0            504273, Asifabad, Adilabad, TELANGANA, India
# 1            504293, Asifabad, Adilabad, TELANGANA, India
# 2               504307, Boath, Adilabad, TELANGANA, India
# 3            504001, Adilabad, Adilabad, TELANGANA, India
# 4            504001, Adilabad, Adilabad, TELANGANA, India
# ...                                                   ...
# 146478  721649, Nandakumar, East Midnapore, WEST BENGA...
# 146479  721151, Panskura-i, East Midnapore, WEST BENGA...
# 146480  721626, Bhagawanpur, East Midnapore, WEST BENG...
# 146481  721139, Panskura-i, East Midnapore, WEST BENGA...
# 146482  721648, Nandakumar, East Midnapore, WEST BENGA...
#
# [146483 rows x 1 columns]

# %%
'''def get_latlng(df, geolocator, pincode):
    location = geolocator.geocode((df[pincode]))
    return location.raw['Latitude']['Longitude']'''
# Out:
# "def get_latlng(df, geolocator, pincode):\n    location = geolocator.geocode((df[pincode]))\n    return location.raw['Latitude']['Longitude']"

# %%
'''geolocator = geopy.Nominatim(user_agent='my-application')
zipcodes = df.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='Lat', lon_field='Lon')'''
# Out:
# "geolocator = geopy.Nominatim(user_agent='my-application')\nzipcodes = df.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='Lat', lon_field='Lon')"

# %%
import requests
from urllib.parse import urlencode

# %%
data_type = 'json'
endpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
params = {"address" : "504273, IN", "key" : api_key}
url_params = urlencode(params)

url = f"{endpoint}?{url_params}"
print(url)
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=504273%2C+IN&key=AIzaSyDiuEDivm4tp6kRQxyYkB7CdKaNXbnO6as

# %%
def extract_lat_lng(address, data_type = 'json'):
    endpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
    params = {"address":"504273, IN"  , "key": api_key}
    url_params = urlencode(params)
    url = f"{endpoint}?{url_params}"
    r = requests.get(url)
    if r.status_code not in range(100, 299): 
        return {}
    latlng = {}
    try:
        latlng = r.json()['results'][0]['geometry']['location']
    except:
        pass
    return latlng.get("lat"), latlng.get("lng")

# %%
extract_lat_lng("Asifabad, Adilabad, TELANGANA, 504273, IN")
# Out:
# (None, None)
